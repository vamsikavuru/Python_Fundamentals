# %%
mylist = ["a", 2, 3+4j, 456, True]
mylist
# Out:
# ['a', 2, (3+4j), 456, True]

# %%
mylist[0:2]
mylist.append("a")
mylist
# Out:
# ['a', 2, (3+4j), 456, True, 'a']

# %%
type(mylist)
# Out:
# list

# %%
list1 = ["abc", 34, True, 40, "male"]
type(list1)
# Out:
# list

# %%
list2  = list((2,4,5,6,7,123))
type(list2)
list2
# Out:
# [2, 4, 5, 6, 7, 123]

# %%
list2[3]
# Out:
# 6

# %%
list2[2::3]
# Out:
# [5, 123]

# %%
list2[:3]
# Out:
# [2, 4, 5]

# %%
list2[2:]
# Out:
# [5, 6, 7, 123]

# %%
list2[-3:-1]
list2[-1]
# Out:
# 123

# %%
list4  = ["a", "b", "c", "d", "e",4]
if 4 in list4:
    print("yes, its present")
else:
    print("no, its not present")
# Out:
# yes, its present

# %%
list4[3] = 67

# %%
list4
# Out:
# ['a', 'b', 'c', 67, 'e', 4]

# %%
list4[1:2] = [34,23]

# %%
list4
# Out:
# ['a', 34, 23, 'c', 67, 'e', 4]

# %%
list4[1:2]
# Out:
# [34]
